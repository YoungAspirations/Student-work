# %% [markdown]
# # Week 2 Results

# %%
from numpy import loadtxt as load, unique, poly1d, polyfit
from pylab import plot, legend, xlabel, ylabel, title
import matplotlib.pyplot as plt
Temperature = [10, 250, 500, 750, 1000, 1250, 1500]
Volume_Glass = [10101, 1.0158E+04, 10230, 1.0299E+04 , 10314, 1.0329E+04, 10342]
Volume_NaCl = [11377, 1.1269E+04, 11524, 1.1969E+04, 12620,1.9625E+04, 23457]
error_GV = [1.0074E+01, 3.0489E+01, 4.4479E+01, 4.5637E+01, 4.6087E+01, 5.0501E+01, 4.6687E+01]
error_NV = [2.3093E+00, 4.3517E+00, 7.3580E+00, 2.2339E+01, 2.8695E+01,6.4726E+02, 1.1543E+03]
plt.subplot(2,1,1)
plot(Temperature, Volume_Glass, 'ro',label ='Glass')
plot(unique(Temperature), poly1d(polyfit(Temperature, Volume_Glass, 1))(unique(Temperature)))
plt.errorbar(Temperature, Volume_Glass, error_GV, linestyle = 'None', marker = '^' )
xlabel('Temperature (K)')
ylabel('Volume (Å³)')
title('Fluctuation of volume of 2 materials at different temperatures')
legend()

plt.subplot(2,1,2)
plot(Temperature, Volume_NaCl, 'bo', label ='NaCl')
plot(unique(Temperature), poly1d(polyfit(Temperature, Volume_NaCl, 1))(unique(Temperature)))
plt.errorbar(Temperature, Volume_NaCl, error_NV, linestyle = 'None', marker = '^' )
xlabel('Temperature (K)')
ylabel('Volume (Å³)')
legend()

alpha_continuousGlass = (1/Volume_Glass[0])*((Volume_Glass[3]-Volume_Glass[0])/(Temperature[3]-Temperature[0]))
alpha_continuousNaCl = (1/Volume_NaCl[0])*((Volume_NaCl[3]-Volume_NaCl[0])/(Temperature[3]-Temperature[0]))
print(alpha_continuousGlass, alpha_continuousNaCl)
#Take gradient of linear reason
# Out:
# <img src="data:image/png;base64,..." width="640">
# 2.6489215678404867e-05 7.031730684714776e-05

# %% [markdown]
# # Week 3 Results

# %%
Glass_Energy, Glass_Temperature, Glass_Volume = load("Week3GlassEnergy"), load("Week3GlassTemperature"), load("Week3GlassVolume")
NaCl_Energy, NaCl_Temperature, NaCl_Volume = load("Week3NaClEnergy"), load("Week3NaClTemperature"), load("Week3NaClVolume")

plt.subplot(3,1,1)
plot(Glass_Energy[:,0], Glass_Energy[:,1]*-1)
plt.subplot(3,1,2)
plot(Glass_Temperature[:,0], Glass_Temperature[:,1])
plt.subplot(3,1,3)
plot(Glass_Volume[:,0], Glass_Volume[:,1])

# %%
plt.subplot(3,1,1)
plot(NaCl_Energy[:,0], NaCl_Energy[:,1]*-1)
plt.subplot(3,1,2)
plot(NaCl_Temperature[:,0], NaCl_Temperature[:,1])
plt.subplot(3,1,3)
plot(NaCl_Volume[:,0], NaCl_Volume[:,1])

# %% [markdown]
# # Week 4 Results

# %%
Week4data = load('Week4Values')
plt.subplot(2,1,1)
plot(Week4data[:,0], Week4data[:,1], label ='av vsi')
legend()
plt.subplot(2,1,2)
plot(Week4data[:,0], Week4data[:,2], label ='av vo')
legend()
#Construct a graph for the cariation in temperature

# %%
pico = 1e-24
ang = 1e-20
msil = 28 * 1.66053906660e-27
mox = 16 * 1.66053906660e-27
mox2 = 16 * 2 * 1.66053906660e-27
N = 6.022140857e23 #Avogrados constant
R = 8.3144598e-2 #molar gas constant
kb = 1.380649e-23 #boltzman constant

av_vsi, av_vo = Week4data[:,1], Week4data[:,2]

udataVSi = []
ldataVO = []

for i in av_vsi:
    udataVSi1 = ((i*ang) / (pico))
    udataVSi.append(udataVSi1)

for i in av_vo:
    ldataVO1 = ((i*ang) / (pico))
    ldataVO.append(ldataVO1)
    
kvsil = []
kvox = []

for i in udataVSi:
    kvsil1 = ((i*msil) / (2) )
    kvsil.append(kvsil1)
    
for i in ldataVO:
    kvox1 = ((i*mox) / (2) )
    kvox.append(kvox1)

tempsil = []
tempvox = []

tempsil = []
tempvox = []


for i in kvsil:
    tempsil1 = ((i*2) / (3*kb) )
    tempsil.append(tempsil1)
    
for i in kvox:
    tempvox1 = ((i*2) / (3*kb) )
    tempvox.append(tempvox1)

print(tempsil)
print(tempvox)

# %matplotlib notebook
plt.subplot(2,1,1)
plt.title('A graph of temperature as a function of time')
plt.grid()
xlabel("Timestep")
ylabel("Temperature")
plot(Week4data[:,0], tempsil, "-")

plt.subplot(2,1,2)
plot(Week4data[:,0], tempvox, "-")
# Out:
# [307.7086245914781, 311.9615567345501, 296.00325972273214, 280.5280980438589, 327.71882668350366, 285.1810053649124, 302.2259847531897, 308.52790848796315, 307.75467912129204, 306.3744318113042, 267.83995777449115, 306.23029517598684, 294.76250509189026, 293.2399621154322, 319.9991234476407, 305.91067492056027, 291.55180715303726, 314.2480782092219, 314.7884654282312, 297.0091392823863, 295.0383192690888, 288.9013654262398, 303.0697838439762, 262.65798968300663, 276.33062059714155, 281.95709735203866, 269.26934211457, 334.37407050648545, 276.7343630260081, 310.1741623258702, 293.5822565963129, 321.6648612466949, 291.8602300522132, 315.2867157889368, 271.6895111922979, 276.40277422799073, 265.4479656230034, 310.5922934978366, 299.59288629998343, 301.6258614627141, 308.9485653793845, 302.7401651071337, 289.7559128564848, 296.8471239209533, 292.1521223981914, 307.3090557736932, 296.9445426041466, 304.06420786272434, 313.93556701215476, 292.6151316759766, 325.36824286057464, 280.91927361
# ...

# %% [markdown]
# ## Week 5 Result

# %%
Pressure0GPa, Pressure3GPa, Pressure6GPa, Pressure10GPa = load("Pressure0GPa"),load("Pressure3GPa"),load("Pressure6GPa"),load("Pressure10GPa")
plot(Pressure0GPa[:,0], Pressure0GPa[:,1], 'r-', label ='Pressure0GPa')
plot(Pressure3GPa[:,0], Pressure3GPa[:,1], 'b-', label ='Pressure3GPa')
plot(Pressure6GPa[:,0], Pressure6GPa[:,1], 'g-', label ='Pressure6GPa')
plot(Pressure10GPa[:,0],Pressure10GPa[:,1], 'k-',label ='Pressure10GPa')
xlabel('Time (ps)')
ylabel('Volume (Å³)')
title('The variation of volume at seperate pressures over time')
legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Pressure = [0,3,6,10]
Average_Volume = [1.0212E+04,8.8130E+03, 7.5256E+03,6.5974E+03]
error = [ 2.2837E+01, 1.3115E+01, 1.7213E+01, 1.4982E+01]
plot(Pressure,Average_Volume,'ko')

plot(unique(Pressure), poly1d(polyfit(Pressure, Average_Volume, 1))(unique(Pressure)))
plt.errorbar(Pressure, Average_Volume, error, linestyle = 'None', marker = '^', )
xlabel('Pressure (GPa)')
ylabel('Volume (Å³)')
title('Average volume taken at 4 pressure values')
#Need to change average volume
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Average volume taken at 4 pressure values')

# %%
#At 10GPa
Beta = -Pressure[3]*(Average_Volume[0]/(Average_Volume[3]-Average_Volume[0]))
print(Beta, 'GPa', 'Bulk modulus')
'Change average volume values as they seem incorrect'
# Out:
# 28.252088751175783 GPa Bulk modulus
# 'Change average volume values as they seem incorrect'
