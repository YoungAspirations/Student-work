# %%
from numpy import loadtxt as load, unique, poly1d, polyfit
from pylab import plot, legend, xlabel, ylabel, title
import matplotlib.pyplot as plt
data = load('untitled.txt')
plot(data[:,0], data[:,1])

# %%
data2 = load('untitled1.txt')
plot(data2[:,0], data2[:,1])

# %%
data3 = load('untitled2.txt')
plot(data3[:,0], data3[:,1])

# %%
data4 = load('Week9CCMPNRG') #CCMP Week9 NRG
plot(data4[:,0], data4[:,1])

# %%
N = 6.022140857e23 #Avogrados constant
kb = 1.380649e-23 #boltzman constant
eV = 1.60218e-19
data5 = load('ccmpweek9temps')
plot(data5[:,0],(3/2)*N*kb*data5[:,1])

# %%
# Out:
#   File "<ipython-input-16-4823e376eb37>", line 1
#     0.00000000       300.000000
#                               ^
# SyntaxError: invalid syntax
